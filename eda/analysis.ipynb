# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("arashnic/microsoft-geolife-gps-trajectory-dataset")

print("Path to dataset files:", path)
# Out:
# Running cells with 'system_design (Python 3.13.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n system_design ipykernel --update-deps --force-reinstall'
